# %% [markdown]
# # Exploratory Data Analysis on Weather Data - SparkR

# %% [markdown]
# ## Set up environment

# %%
# Load SparkR library

library(SparkR, lib.loc = c(file.path(Sys.getenv("SPARK_HOME"), "R", "lib")))
# Out:
# Attaching package: ‘SparkR’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, filter, lag, na.omit, predict, sd, var, window
#
# The following objects are masked from ‘package:base’:
#
#     as.data.frame, colnames, colnames<-, drop, endsWith, intersect,
#     rank, rbind, sample, startsWith, subset, summary, transform, union

# %%
# Start Spark session

sparkR.session(master="local[*]", sparkConfig=list(spark.driver.memory="2g"))
# Out:
# Spark package found in SPARK_HOME: /share/apps/compute/spark/spark-2.4.0-bin-hadoop2.6
# Launching java with spark-submit command /share/apps/compute/spark/spark-2.4.0-bin-hadoop2.6/bin/spark-submit   --driver-memory "2g" sparkr-shell /tmp/RtmptCEiMH/backend_port551525fbf7ce
# Java ref type org.apache.spark.sql.SparkSession id 1

# %% [markdown]
# ## Read in data

# %%
# Read data into a Spark dataframeam

sdf <- read.df("daily_weather.csv", "csv", header="true", inferSchema="true")

# %%
# Cache dataframe

cache(sdf)
# Out:
# SparkDataFrame[number:int, air_pressure_9am:double, air_temp_9am:double, avg_wind_direction_9am:double, avg_wind_speed_9am:double, max_wind_direction_9am:double, max_wind_speed_9am:double, rain_accumulation_9am:double, rain_duration_9am:double, relative_humidity_9am:double, relative_humidity_3pm:double]

# %%
# Examine schema

schema(sdf)
# Out:
# StructType
# |-name = "number", type = "IntegerType", nullable = TRUE
# |-name = "air_pressure_9am", type = "DoubleType", nullable = TRUE
# |-name = "air_temp_9am", type = "DoubleType", nullable = TRUE
# |-name = "avg_wind_direction_9am", type = "DoubleType", nullable = TRUE
# |-name = "avg_wind_speed_9am", type = "DoubleType", nullable = TRUE
# |-name = "max_wind_direction_9am", type = "DoubleType", nullable = TRUE
# |-name = "max_wind_speed_9am", type = "DoubleType", nullable = TRUE
# |-name = "rain_accumulation_9am", type = "DoubleType", nullable = TRUE
# |-name = "rain_duration_9am", type = "DoubleType", nullable = TRUE
# |-name = "relative_humidity_9am", type = "DoubleType", nullable = TRUE
# |-name = "relative_humidity_3pm", type = "DoubleType", nullable = TRUE

# %% [markdown]
# ## Explore data

# %%
# Show summary statistics

head(summary(sdf))
# Out:
#   summary number             air_pressure_9am  air_temp_9am
# 1 count   1095               1092              1090
# 2 mean    547.0              918.8825513138094 64.93300141287072
# 3 stddev  316.24357700987383 3.184161180386833 11.175514003175877
# 4 min     0                  907.9900000000024 36.752000000000685
# 5 25%     273                916.550000000009  57.272000000000354
# 6 50%     547                918.9020905167166 65.69599999999856
#   avg_wind_direction_9am avg_wind_speed_9am max_wind_direction_9am
# 1 1091                   1092               1092
# 2 142.2355107005759      5.50828424225493   148.95351796516923
# 3 69.13785928889189      4.5528134655317185 67.23801294602953
# 4 15.500000000000046     0.69345139999974   28.89999999999991
# 5 65.88061551980813      2.2482786234616317 76.45666344425672
# 6 166.0                  3.8699061999999844 177.09999999999994
#   max_wind_speed_9am rain_accumulation_9am rain_duration_9am
# 1 1091               1089                  1092
# 2 7.019513529175272  0.20307895225211126   294.1080522756142
# 3 5.598209170780958  1.5939521253574893    1598.0787786601481
# 4 1.1855782000000479 0.0                   0.0
# 5 3.0646077999999797 0.0                   0.0
# 6 4.943637399999937  0.0                   0.0
#   relative_humidity_9am relative_humidity_3pm
# 1 1095                  1095
# 2 34.24140205923536     35.34472714825898
# 3 25.472066802250055    22.524079453587273
# 4 6.090000000001012     5.3000000000006855
# 5 15.090000000000687    17.390000000000576
# 6 23.179259298119568    24.380000000000344

# %%
# Get number of rows

nrow(sdf)
# Out:
# [1] 1095

# %%
# Show first few rows

head(sdf)
# Out:
#   number air_pressure_9am air_temp_9am avg_wind_direction_9am
# 1 0      918.0600         74.82200     271.1000
# 2 1      917.3477         71.40384     101.9352
# 3 2      923.0400         60.63800      51.0000
# 4 3      920.5028         70.13889     198.8321
# 5 4      921.1600         44.29400     277.8000
# 6 5      915.3000         78.40400     182.8000
#   avg_wind_speed_9am max_wind_direction_9am max_wind_speed_9am
# 1  2.080354          295.4000                2.863283
# 2  2.443009          140.4715                3.533324
# 3 17.067852           63.7000               22.100967
# 4  4.337363          211.2033                5.190045
# 5  1.856660          136.5000                2.863283
# 6  9.932014          189.0000               10.983375
#   rain_accumulation_9am rain_duration_9am relative_humidity_9am
# 1 0.00                      0             42.4200
# 2 0.00                      0             24.3287
# 3 0.00                     20              8.9000
# 4 0.00                      0             12.1891
# 5 8.90                  14730             92.4100
# 6 0.02                    170             35.1300
#   relative_humidity_3pm
# 1 36.16000
# 2 19.42660
# 3 14.46000
# 4 12.74255
# 5 76.74000
# 6 33.93000

# %%
# Get column names

names(sdf)
# Out:
#  [1] "number"                 "air_pressure_9am"       "air_temp_9am"
#  [4] "avg_wind_direction_9am" "avg_wind_speed_9am"     "max_wind_direction_9am"
#  [7] "max_wind_speed_9am"     "rain_accumulation_9am"  "rain_duration_9am"
# [10] "relative_humidity_9am"  "relative_humidity_3pm"

# %%
# Get number of columns

ncol(sdf)
# Out:
# [1] 11

# %%
# Correlation between air_temp_9am and relative_humidity_9am 

corr(sdf, 'air_temp_9am', 'relative_humidity_9am', method = "pearson")
# Out:
# [1] -0.5366701

# %%
# Scatter plot of air_temp_9am and relative_humidity_9am 

df <- as.data.frame(sdf)
plot(df$air_temp_9am, df$relative_humidity_9am, col='blue')
# Out:
# plot without title

# %%
# Histogram of air_temp_9am

hist(df$air_temp_9am, col="lightblue")
# Out:
# Plot with title “Histogram of df$air_temp_9am”

# %% [markdown]
# ## Stop Spark session

# %%
sparkR.stop()
